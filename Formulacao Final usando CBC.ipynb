# %%
using Cbc
using JuMP

# %%
m = Model();

# %%
set_optimizer(m, Cbc.Optimizer)

# %%
f = open("C:/Users/gabri/OneDrive/Documents/2021-1/Otimização/Trabalho Final/Problema1-instancias/Problema1/induced_50_368.dat", "r");

# %%
file = read(f, String);

# %%
rawList = split(file, "\n")
rawList = convert(Vector{String}, rawList)
inputFile = []
for (index, value) in enumerate(rawList)
           append!(inputFile,  [convert(Vector{String},split(value, " "))])
       end
pop!(inputFile);

# %%
@variable(m, NV >=0)
NumberVertices=parse(Int64,inputFile[1][1])
popfirst!(inputFile)
NV = collect(1:NumberVertices);

# %%
@variable(m, G[x in NV, y in NV])
@variable(m, M[x in NV, y in NV], Bin)
@variable(m, X[x in NV] >=0, Int)
@variable(m, Vec[x in NV], Bin);

# %%
G = zeros(Int64, NumberVertices, NumberVertices)
for (index, value) in enumerate(inputFile)
    x = parse(Int64, value[1])
    y = parse(Int64, value[2])
    G[x,y] = 1
    G[y,x] = 1
       end
;

# %%
@objective(m, Max, sum(Vec[i] for i in NV));

# %%
@constraint(m, [i in NV, j in NV], M[i,j] >= (Vec[i] + Vec[j]) * G[i,j] - 1) # Isso é equivalente à 
@constraint(m, [i in NV, j in NV], M[i,j] <= (Vec[i] + Vec[j]) * G[i,j] / 2) # Vec[i] and Vec[j] * G[i,j]
@constraint(m, [i in NV], sum(M[i,j] for j in NV) == 2*X[i]);

# %%
set_time_limit_sec(m, 3600.0);

# %%
optimize!(m)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.5
# Build Date: Jan  1 1970
#
# command line - Cbc_C_Interface -seconds 60.0 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 60
# Continuous objective value is 50 - 0.01 seconds
# Cgl0002I 1764 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 0 strengthened rows, 736 substitutions
# Cgl0004I processed model has 786 rows, 468 columns (468 integer (418 of which binary)) and 2994 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 50 integer variables out of 468 objects (468 integer) have cost of -1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 354 integers unsatisfied sum - 23.8937
# Cbc0038I Pass   1: suminf.   18.22688 (332) obj. -48.4024 iterations 254
# Cbc0038I Pass   2: suminf.   19.89618 (209) obj. -46.367 iterations 84
# Cbc0038I Pass   3: suminf.   17.12868 (195) obj. -45.9643 iterations 19
# Cbc0038I Pass   4: suminf.   10.00957 (169) obj. -45.9581 iterations 23
# Cbc0038I Pass   5: suminf.   10.77147 (146) obj. -45.4583 iterations 4
# Cbc0038I Pass   6: suminf.   10.56819 (108) obj. -45.3364 iterations 10
# Cbc0038I Pass   7: suminf.    6.06819 (99) obj. -45.3364 iterations 14
# Cbc0038I Pass   8: suminf.    7.87047 (69) obj. -44.5829 iterations 4
# Cbc0038I Pass   9: suminf.    3.84824 (61) obj. -44.6829 iterations 34
# Cbc0038I Pass  10: suminf.    8.50000 (17) obj. -42 iterations 5
# Cbc0038I Pass  11: suminf.    0.00000 (0) obj. -42 iterations 17
# Cbc0038I Solution found of -42
# Cbc0038I Cleaned solution of -42
# Cbc0038I Before mini branch and bound, 86 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 786 rows 468 columns, reduced to 636 rows 332 columns - 63 fixed gives 192, 99 - ok now
# Cbc0038I Full problem 786 rows 468 columns, reduced to 140 rows 70 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -43.5681
# Cbc0038I Pass  12: suminf.   18.22688 (332) obj. -48.4024 iterations 0
# Cbc0038I Pass  13: suminf.   20.53724 (296) obj. -47.2754 iterations 37
# Cbc0038I Pass  14: suminf.   19.59901 (278) obj. -46.8348 iterations 27
# Cbc0038I Pass  15: suminf.   12.10388 (216) obj. -46.8039 iterations 44
# Cbc0038I Pass  16: suminf.   12.36973 (216) obj. -46.7191 iterations 11
# Cbc0038I Pass  17: suminf.   22.48214 (146) obj. -43.5681 iterations 119
# Cbc0038I Pass  18: suminf.    6.16783 (34) obj. -43.8322 iterations 127
# Cbc0038I Pass  19: suminf.    2.16783 (26) obj. -43.8322 iterations 23
# Cbc0038I Pass  20: suminf.    6.46861 (48) obj. -43.5681 iterations 105
# Cbc0038I Pass  21: suminf.    3.07692 (37) obj. -43.682 iterations 56
# Cbc0038I Pass  22: suminf.    4.60325 (34) obj. -43.5681 iterations 45
# Cbc0038I Pass  23: suminf.    2.00000 (23) obj. -43.7589 iterations 87
# Cbc0038I Pass  24: suminf.    4.13756 (23) obj. -43.5681 iterations 18
# Cbc0038I Pass  25: suminf.   12.36204 (62) obj. -43.5681 iterations 127
# Cbc0038I Pass  26: suminf.   13.72323 (82) obj. -43.5681 iterations 139
# Cbc0038I Pass  27: suminf.   15.19820 (60) obj. -43.5681 iterations 171
# Cbc0038I Pass  28: suminf.   17.60117 (64) obj. -43.5681 iterations 145
# Cbc0038I Pass  29: suminf.    1.11111 (10) obj. -43.8889 iterations 144
# Cbc0038I Pass  30: suminf.    4.31925 (10) obj. -43.5681 iterations 59
# Cbc0038I Pass  31: suminf.   10.43111 (64) obj. -43.5681 iterations 169
# Cbc0038I Pass  32: suminf.   14.54566 (75) obj. -43.5681 iterations 205
# Cbc0038I Pass  33: suminf.   16.47014 (89) obj. -43.5681 iterations 188
# Cbc0038I Pass  34: suminf.   19.05540 (56) obj. -43.5681 iterations 151
# Cbc0038I Pass  35: suminf.   19.45540 (42) obj. -43.5681 iterations 147
# Cbc0038I Pass  36: suminf.   19.51752 (54) obj. -43.5681 iterations 171
# Cbc0038I Pass  37: suminf.    2.20202 (22) obj. -43.798 iterations 138
# Cbc0038I Pass  38: suminf.    4.41925 (22) obj. -43.5681 iterations 53
# Cbc0038I Pass  39: suminf.   12.41113 (62) obj. -43.5681 iterations 166
# Cbc0038I Pass  40: suminf.   17.80047 (64) obj. -43.5681 iterations 199
# Cbc0038I Pass  41: suminf.   24.88697 (117) obj. -43.5681 iterations 199
# Cbc0038I Pass  42: suminf.    9.11111 (26) obj. -43.8889 iterations 143
# Cbc0038I Pass  43: suminf.    1.11111 (10) obj. -43.8889 iterations 39
# Cbc0038I Pass  44: suminf.    4.31925 (10) obj. -43.5681 iterations 65
# Cbc0038I Pass  45: suminf.   11.33099 (28) obj. -43.5681 iterations 96
# Cbc0038I Pass  46: suminf.    0.00000 (0) obj. -44 iterations 126
# Cbc0038I Solution found of -44
# Cbc0038I Cleaned solution of -44
# Cbc0038I Before mini branch and bound, 33 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 786 rows 468 columns, reduced to 724 rows 385 columns - 237 fixed gives 302, 148 - ok now
# Cbc0038I Full problem 786 rows 468 columns, reduced to 302 rows 148 columns
# Cbc0038I Mini branch and bound did not improve solution (0.17 seconds)
# Cbc0038I Round again with cutoff of -45.7363
# Cbc0038I Pass  47: suminf.   18.22688 (332) obj. -48.4024 iterations 0
# Cbc0038I Pass  48: suminf.   19.83614 (209) obj. -46.3338 iterations 84
# Cbc0038I Pass  49: suminf.   17.12868 (195) obj. -45.9643 iterations 17
# Cbc0038I Pass  50: suminf.   10.00957 (169) obj. -45.9581 iterations 22
# Cbc0038I Pass  51: suminf.   11.34627 (169) obj. -45.7363 iterations 6
# Cbc0038I Pass  52: suminf.    9.49048 (115) obj. -45.7363 iterations 116
# Cbc0038I Pass  53: suminf.    5.42332 (86) obj. -45.7363 iterations 98
# Cbc0038I Pass  54: suminf.    5.42332 (86) obj. -45.7363 iterations 0
# Cbc0038I Pass  55: suminf.    6.91414 (138) obj. -45.7363 iterations 86
# Cbc0038I Pass  56: suminf.    3.87100 (61) obj. -45.7363 iterations 81
# Cbc0038I Pass  57: suminf.    3.89375 (61) obj. -45.7363 iterations 13
# Cbc0038I Pass  58: suminf.    8.46684 (93) obj. -45.7363 iterations 182
# Cbc0038I Pass  59: suminf.    4.37100 (62) obj. -45.7363 iterations 120
# Cbc0038I Pass  60: suminf.    6.86425 (99) obj. -45.7363 iterations 111
# Cbc0038I Pass  61: suminf.    5.37100 (64) obj. -45.7363 iterations 90
# Cbc0038I Pass  62: suminf.    9.40136 (151) obj. -45.7363 iterations 155
# Cbc0038I Pass  63: suminf.    4.43153 (63) obj. -45.7363 iterations 150
# Cbc0038I Pass  64: suminf.    3.87100 (61) obj. -45.7363 iterations 33
# Cbc0038I Pass  65: suminf.    7.66788 (84) obj. -45.7363 iterations 86
# Cbc0038I Pass  66: suminf.    4.09091 (41) obj. -45.7363 iterations 87
# Cbc0038I Pass  67: suminf.    3.09091 (39) obj. -45.7363 iterations 2
# Cbc0038I Pass  68: suminf.    3.25687 (39) obj. -45.7363 iterations 43
# Cbc0038I Pass  69: suminf.    8.63454 (69) obj. -45.7363 iterations 164
# Cbc0038I Pass  70: suminf.    6.09091 (45) obj. -45.7363 iterations 119
# Cbc0038I Pass  71: suminf.   11.34213 (122) obj. -45.7363 iterations 198
# Cbc0038I Pass  72: suminf.    5.59091 (44) obj. -45.7363 iterations 150
# Cbc0038I Pass  73: suminf.   15.81263 (146) obj. -45.7363 iterations 194
# Cbc0038I Pass  74: suminf.    6.27116 (47) obj. -45.7363 iterations 167
# Cbc0038I Pass  75: suminf.    3.09091 (39) obj. -45.7363 iterations 67
# Cbc0038I Pass  76: suminf.    3.11155 (51) obj. -45.7363 iterations 70
# Cbc0038I Pass  77: suminf.    7.58892 (80) obj. -45.7363 iterations 183
# Cbc0038I Pass  78: suminf.    3.70504 (41) obj. -45.7363 iterations 142
# Cbc0038I Pass  79: suminf.   10.16162 (130) obj. -45.7363 iterations 216
# Cbc0038I Pass  80: suminf.    5.09091 (43) obj. -45.7363 iterations 161
# Cbc0038I Pass  81: suminf.    9.49643 (123) obj. -45.7363 iterations 201
# Cbc0038I Pass  82: suminf.    5.59091 (44) obj. -45.7363 iterations 183
# Cbc0038I Pass  83: suminf.    3.09091 (39) obj. -45.7363 iterations 17
# Cbc0038I Pass  84: suminf.    3.19127 (39) obj. -45.7363 iterations 48
# Cbc0038I Pass  85: suminf.    7.78431 (78) obj. -45.7363 iterations 138
# Cbc0038I Pass  86: suminf.    3.59091 (40) obj. -45.7363 iterations 145
# Cbc0038I Pass  87: suminf.   13.15250 (163) obj. -45.7363 iterations 213
# Cbc0038I Pass  88: suminf.    4.18103 (42) obj. -45.7363 iterations 134
# Cbc0038I Pass  89: suminf.   10.12981 (138) obj. -45.7363 iterations 143
# Cbc0038I Pass  90: suminf.    3.59091 (40) obj. -45.7363 iterations 148
# Cbc0038I Pass  91: suminf.    3.09091 (39) obj. -45.7363 iterations 1
# Cbc0038I Pass  92: suminf.    3.23069 (39) obj. -45.7363 iterations 35
# Cbc0038I Pass  93: suminf.    8.41300 (59) obj. -45.7363 iterations 156
# Cbc0038I Pass  94: suminf.    4.09091 (41) obj. -45.7363 iterations 132
# Cbc0038I Pass  95: suminf.   12.66435 (151) obj. -45.7363 iterations 246
# Cbc0038I Pass  96: suminf.    4.52882 (59) obj. -45.7363 iterations 186
# Cbc0038I Pass  97: suminf.    9.59343 (101) obj. -45.7363 iterations 156
# Cbc0038I Pass  98: suminf.    4.59091 (42) obj. -45.7363 iterations 154
# Cbc0038I Pass  99: suminf.    3.09091 (39) obj. -45.7363 iterations 4
# Cbc0038I Pass 100: suminf.    3.25687 (39) obj. -45.7363 iterations 70
# Cbc0038I Pass 101: suminf.    7.78776 (113) obj. -45.7363 iterations 192
# Cbc0038I Pass 102: suminf.    4.18103 (42) obj. -45.7363 iterations 194
# Cbc0038I Pass 103: suminf.    8.69816 (101) obj. -45.7363 iterations 157
# Cbc0038I Pass 104: suminf.    4.59091 (42) obj. -45.7363 iterations 164
# Cbc0038I Pass 105: suminf.    8.86204 (73) obj. -45.7363 iterations 141
# Cbc0038I Pass 106: suminf.    4.68103 (43) obj. -45.7363 iterations 149
# Cbc0038I Pass 107: suminf.    3.09091 (39) obj. -45.7363 iterations 40
# Cbc0038I Pass 108: suminf.    3.14790 (39) obj. -45.7363 iterations 38
# Cbc0038I Pass 109: suminf.    3.68042 (41) obj. -45.7363 iterations 228
# Cbc0038I Pass 110: suminf.    9.34557 (95) obj. -45.7363 iterations 210
# Cbc0038I Pass 111: suminf.    5.09091 (43) obj. -45.7363 iterations 178
# Cbc0038I Pass 112: suminf.    6.56790 (59) obj. -45.7363 iterations 209
# Cbc0038I Pass 113: suminf.    9.30810 (109) obj. -45.7363 iterations 167
# Cbc0038I Pass 114: suminf.    4.70504 (43) obj. -45.7363 iterations 160
# Cbc0038I Pass 115: suminf.    9.58657 (86) obj. -45.7363 iterations 192
# Cbc0038I Pass 116: suminf.    6.09091 (45) obj. -45.7363 iterations 138
# Cbc0038I Pass 117: suminf.    3.09091 (39) obj. -45.7363 iterations 11
# Cbc0038I Pass 118: suminf.    3.10474 (39) obj. -45.7363 iterations 74
# Cbc0038I Pass 119: suminf.    7.17641 (48) obj. -45.7363 iterations 124
# Cbc0038I Pass 120: suminf.   12.11411 (166) obj. -45.7363 iterations 233
# Cbc0038I Pass 121: suminf.    4.09091 (41) obj. -45.7363 iterations 204
# Cbc0038I Pass 122: suminf.    8.10368 (82) obj. -45.7363 iterations 195
# Cbc0038I Pass 123: suminf.    4.59091 (42) obj. -45.7363 iterations 171
# Cbc0038I Pass 124: suminf.    5.37404 (46) obj. -45.7363 iterations 194
# Cbc0038I Pass 125: suminf.   14.03068 (160) obj. -45.7363 iterations 225
# Cbc0038I Pass 126: suminf.    7.07690 (64) obj. -45.7363 iterations 196
# Cbc0038I Pass 127: suminf.    3.09091 (39) obj. -45.7363 iterations 34
# Cbc0038I Pass 128: suminf.    3.14790 (39) obj. -45.7363 iterations 42
# Cbc0038I Pass 129: suminf.    6.97171 (87) obj. -45.7363 iterations 174
# Cbc0038I Pass 130: suminf.    4.09091 (41) obj. -45.7363 iterations 221
# Cbc0038I Pass 131: suminf.    6.94388 (97) obj. -45.7363 iterations 191
# Cbc0038I Pass 132: suminf.    4.09091 (41) obj. -45.7363 iterations 169
# Cbc0038I Pass 133: suminf.    7.27194 (48) obj. -45.7363 iterations 127
# Cbc0038I Pass 134: suminf.    9.92843 (115) obj. -45.7363 iterations 186
# Cbc0038I Pass 135: suminf.    5.09091 (43) obj. -45.7363 iterations 159
# Cbc0038I Pass 136: suminf.    3.09091 (39) obj. -45.7363 iterations 5
# Cbc0038I Pass 137: suminf.    3.18757 (51) obj. -45.7363 iterations 72
# Cbc0038I Pass 138: suminf.   13.00058 (183) obj. -45.7363 iterations 219
# Cbc0038I Pass 139: suminf.    4.70467 (43) obj. -45.7363 iterations 198
# Cbc0038I Pass 140: suminf.    7.62358 (58) obj. -45.7363 iterations 160
# Cbc0038I Pass 141: suminf.    4.09091 (41) obj. -45.7363 iterations 140
# Cbc0038I Pass 142: suminf.    6.88149 (99) obj. -45.7363 iterations 194
# Cbc0038I Pass 143: suminf.    3.68103 (41) obj. -45.7363 iterations 195
# Cbc0038I Pass 144: suminf.    3.09091 (39) obj. -45.7363 iterations 25
# Cbc0038I Pass 145: suminf.    3.25687 (39) obj. -45.7363 iterations 48
# Cbc0038I Pass 146: suminf.    8.31056 (72) obj. -45.7363 iterations 172
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 79 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 786 rows 468 columns, reduced to 648 rows 339 columns - 198 fixed gives 278, 135 - ok now
# Cbc0038I Full problem 786 rows 468 columns, reduced to 278 rows 135 columns
# Cbc0038I Mini branch and bound did not improve solution (0.56 seconds)
# Cbc0038I After 0.56 seconds - Feasibility pump exiting with objective of -44 - took 0.53 seconds
# Cbc0031I 74 added rows had average density of 67.054054
# Cbc0013I At root node, 74 cuts changed objective from -48.68165 to -47.039739 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 3021 row cuts average 2.0 elements, 0 column cuts (3 active)  in 0.134 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1766 row cuts average 396.5 elements, 0 column cuts (0 active)  in 1.259 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1443 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.265 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 1.260 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.079 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 166 row cuts average 266.6 elements, 0 column cuts (0 active)  in 0.536 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -47.039739 (5.77 seconds)
# Cbc0010I After 1000 nodes, 42 on tree, 1e+50 best solution, best possible -47.039739 (11.22 seconds)
# Cbc0010I After 2000 nodes, 73 on tree, 1e+50 best solution, best possible -47.039738 (14.40 seconds)
# Cbc0010I After 3000 nodes, 76 on tree, 1e+50 best solution, best possible -47.039738 (16.27 seconds)
# Cbc0010I After 4000 nodes, 76 on tree, 1e+50 best solution, best possible -47.039738 (18.10 seconds)
# Cbc0010I After 5000 nodes, 74 on tree, 1e+50 best solution, best possible -47.039738 (20.06 seconds)
# Cbc0010I After 6000 nodes, 105 on tree, 1e+50 best solution, best possible -47.039733 (21.99 seconds)
# Cbc0010I After 7000 nodes, 107 on tree, 1e+50 best solution, best possible -47.039733 (23.47 seconds)
# Cbc0010I After 8000 nodes, 107 on tree, 1e+50 best solution, best possible -47.039733 (24.89 seconds)
# Cbc0010I After 9000 nodes, 110 on tree, 1e+50 best solution, best possible -47.039733 (26.41 seconds)
# Cbc0010I After 10000 nodes, 140 on tree, 1e+50 best solution, best possible -47.035216 (28.41 seconds)
# Cbc0010I After 11000 nodes, 142 on tree, 1e+50 best solution, best possible -47.035216 (29.89 seconds)
# Cbc0010I After 12000 nodes, 626 on tree, 1e+50 best solution, best possible -45.128194 (42.81 seconds)
# Cbc0010I After 13000 nodes, 1114 on tree, 1e+50 best solution, best possible -44.915233 (52.96 seconds)
# Cbc0010I After 14000 nodes, 1126 on tree, 1e+50 best solution, best possible -44.914801 (54.66 seconds)
# Cbc0010I After 15000 nodes, 1130 on tree, 1e+50 best solution, best possible -44.914801 (56.29 seconds)
# Cbc0010I After 16000 nodes, 1124 on tree, 1e+50 best solution, best possible -44.914801 (58.23 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 1e+50 (best possible -44.914801), took 776167 iterations and 16967 nodes (59.99 seconds)
# Cbc0032I Strong branching done 10306 times (167257 iterations), fathomed 794 nodes and fixed 1074 variables
# Cbc0035I Maximum depth 49, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -48.6817 to -47.0397
# Probing was tried 6939 times and created 435171 cuts of which 3 were active after adding rounds of cuts (4.358 seconds)
# Gomory was tried 100 times and created 1766 cuts of which 0 were active after adding rounds of cuts (1.259 seconds)
# Knapsack was tried 4399 times and created 22386 cuts of which 0 were active after adding rounds of cuts (3.393 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (1.260 seconds)
# FlowCover was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.079 seconds)
# TwoMirCuts was tried 100 times and created 166 cuts of which 0 were active after adding rounds of cuts (0.536 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# ImplicationCuts was tried 779 times and created 18164 cuts of which 0 were active after adding rounds of cuts (0.469 seconds)
#
# Result - Stopped on time limit
#
# No feasible solution found
# Upper bound:                    44.915
# Enumerated nodes:               16967
# Total iterations:               776167
# Time (CPU seconds):             60.03
# Time (Wallclock seconds):       60.03
#
# Total time (CPU seconds):       60.03   (Wallclock seconds):       60.03
